# %%
# Install Python dependencies from requirements.txt
# !pip install -r requirements.txt
# Out:
# Requirement already satisfied: anyio==4.11.0 in d:\projekty\sieci_neuronowe\.venv\lib\site-packages (from -r requirements.txt (line 1)) (4.11.0)
# Requirement already satisfied: argon2-cffi==25.1.0 in d:\projekty\sieci_neuronowe\.venv\lib\site-packages (from -r requirements.txt (line 2)) (25.1.0)
# Requirement already satisfied: argon2-cffi-bindings==25.1.0 in d:\projekty\sieci_neuronowe\.venv\lib\site-packages (from -r requirements.txt (line 3)) (25.1.0)
# Requirement already satisfied: arrow==1.4.0 in d:\projekty\sieci_neuronowe\.venv\lib\site-packages (from -r requirements.txt (line 4)) (1.4.0)
# Requirement already satisfied: asttokens==3.0.1 in d:\projekty\sieci_neuronowe\.venv\lib\site-packages (from -r requirements.txt (line 5)) (3.0.1)
# Requirement already satisfied: async-lru==2.0.5 in d:\projekty\sieci_neuronowe\.venv\lib\site-packages (from -r requirements.txt (line 6)) (2.0.5)
# Requirement already satisfied: attrs==25.4.0 in d:\projekty\sieci_neuronowe\.venv\lib\site-packages (from -r requirements.txt (line 7)) (25.4.0)
# Requirement already satisfied: babel==2.17.0 in d:\projekty\sieci_neuronowe\.venv\lib\site-packages (from -r requirements.txt (line 8)) (2.17.0)
# Requirement already satisfied: beautifulsoup4==4.14.2 in d:\projekty\sieci_neuronowe\.venv\lib\site-packages (from -r requirements.txt (line 9)) (4.14.2)
# Requirement already satisfied: bleach==6.3.0 in d:\projekty\sieci_neuronowe\.venv\lib\site-packages (from -r requirements.txt (line 10)) (6.3.0)
# Requirement already satisfied: certifi==2025.11.12 in d:\projekty\sieci_neuronowe\.venv\lib\site-packages (from -r requirements.txt (line 11)) (2025.11.12)
# Requirement already satisfied: cffi==2.0.0 in d:\projekty\sieci_neuronowe\.venv\lib\site-packages (from -r requirements.txt (line 12)) (2.0.0)
# Requirement already satisfied: charset-normalizer==3.4.4 in d:\projekty\sieci_neuronowe\.venv\lib\site-packages (from -r requirements.txt (line 13)) (3.4.4)
# Requirement already satisfied: colorama==0.4.6 in d:\projekty\sieci_neuronowe\.venv\lib\site-packages (from -r requirements.txt (line 14)) (0.4.6)
# Requirement already satisfied: comm==0.2.3 in d:\projekty\sieci_neuronowe\.venv\lib\site-packages (from -r requirements.txt (line 15)) (0.2.3)
# Requirement already satisfied: contourpy==1.3.3 in d:\projekty\sieci_neuronowe\.venv\lib\site-packages (from -r requirements.txt (line 16)) (1.3.3)
# Requirement already satisfied: cycler==0.12.1 in d:\projekty\sieci_neuronowe\.venv\lib\site-packages (from -r requirements.txt (line 17)) (0.12.1)
# Requirement already satisfied: debugpy==1.8.17 in d:\projekty\sieci_neuronowe\.venv\lib\site-packages (from -r requirements.txt (line 18)) (1.8.17)
# Requirement already satisfied: decorator==5.2.1 in d:\projekty\sieci_neuronowe\.venv\lib\site-packages (from -r requirements.txt (line 19)) (5.2.1)
# Requirement already satisfied: defusedxml==0.7.1 in d:\projekty\sieci_neuronowe\.venv\lib\site-packages (from -r requirements.txt (line 20)) (0.7.1)
# Requirement already satisfied: docutils==0.22.3 in d:\projekty\sieci_neuronowe\.venv\lib\site-packages (from -r requirements.txt (line 21)) (0.22.3)
# Requirement already satisfied: executing==2.2.1 in d:\projekty\sieci_neuronowe\.venv\lib\site-packages (from -r requirements.txt (line 22)) (2.2.1)
# Requirement already satisfied: fastjsonschema==2.21.2 in d:\projekty\sieci_neuronowe\.venv\lib\site-packages (from -r requirements.txt (line 23)) (2.21.2)
# Requirement already satisfied: filelock==3.19.1 in d:\projekty\sieci_neuronowe\.venv\lib\site-packages (from -r requirements.txt (line 24)) (3.19.1)
# Requirement already satisfied: fonttools==4.60.1 in d:\projekty\sieci_neuronowe\.venv\lib\site-packages (from -r requirements.txt (line 25)) (4.60.1)
# Requirement already satisfied: fqdn==1.5.1 in d:\projekty\sieci_neuronowe\.venv\lib\site-packages (from -r requirements.txt (line 26)) (1.5.1)
# Requirement already satisfied: fsspec==2025.9.0 in d:\projekty\sieci_neuronowe\.venv\lib\site-packages (from -r requirements.txt (line 27)) (2025.9.0)
# Requirement already satisfied: h11==0.16.0 in d:\projekty\sieci_neuronowe\.venv\lib\site-packages (from -r requirements.txt (line 28)) (0.16.0)
# Requirement already satisfied: httpcore==1.0.9 in d:\projekty\sieci_neuronowe\.venv\lib\site-packages (from -r requirements.txt (line 29)) (1.0.9)
# Requirement already satisfied: httpx==0.28.1 in d:\projekty\sieci_neuronowe\.venv\lib\site-packages (from -r requirements.txt (line 30)) (0.28.1)
# Requirement already satisfied: id==1.5.0 in d:\projekty\sieci_neuronowe\.venv\lib\site-packages (from -r requirements.txt (line 31)) (1.5.0)
# Requirement already satisfied: idna==3.11 in d:\projekty\sieci_neuronowe\.venv\lib\site-packages (from -r requirements.txt (line 32)) (3.11)
# Requirement already satisfied: ipykernel==7.1.0 in d:\projekty\sieci_neuronowe\.venv\lib\site-packages (from -r requirements.txt (line 33)) (7.1.0)
# Requirement already satisfied: ipython==9.7.0 in d:\projekty\sieci_neuronowe\.venv\lib\site-packages (from -r requirements.txt (line 34)) (9.7.0)
# Requirement already satisfied: ipython_pygments_lexers==1.1.1 in d:\projekty\sieci_neuronowe\.venv\lib\site-packages (from -r requirements.txt (line 35)) (1.1.1)
# Requirement already satisfied: isoduration==20.11.0 in d:\projekty\sieci_neuronowe\.venv\lib\site-packages (from -r requirements.txt (line 36)) (20.11.0)
# Requirement already satisfied: jaraco.classes==3.4.0 in d:\projekty\sieci_neuronowe\.venv\lib\site-packages (from -r requirements.txt (line 37)) (3.4.0)
# Requirement already satisfied: jaraco.context==6.0.1 in d:\projekty\sieci_neuronowe\.venv\lib\site-packages (from -r requirements.txt (line 38)) (6.0.1)
# Requirement already satisfied: jaraco.functools==4.3.0 in d:\projekty\sieci_neuronowe\.venv\lib\site-packages (from -r requirements.txt (line 39)) (4.3.0)
# Requirement already satisfied: jedi==0.19.2 in d:\projekty\sieci_neuronowe\.venv\lib\site-packages (from -r requirements.txt (line 40)) (0.19.2)
# Requirement already satisfied: Jinja2==3.1.6 in d:\projekty\sieci_neuronowe\.venv\lib\site-packages (from -r requirements.txt (line 41)) (3.1.6)
# Requirement already satisfied: json5==0.12.1 in d:\projekty\sieci_neuronowe\.venv\lib\site-packages (from -r requirements.txt (line 42)) (0.12.1)
# Requirement already satisfied: jsonpointer==3.0.0 in d:\projekty\sieci_neuronowe\.venv\lib\site-packages (from -r requirements.txt (line 43)) (3.0.0)
# Requirement already satisfied: jsonschema==4.25.1 in d:\projekty\sieci_neuronowe\.venv\lib\site-packages (from -r requirements.txt (line 44)) (4.25.1)
# Requirement already satisfied: jsonschema-specifications==2025.9.1 in d:\projekty\sieci_neuronowe\.venv\lib\site-packages (from -r requirements.txt (line 45)) (2025.9.1)
# Requirement already satisfied: jupyter-events==0.12.0 in d:\projekty\sieci_neuronowe\.venv\lib\site-packages (from -r requirements.txt (line 46)) (0.12.0)
# Requirement already satisfied: jupyter-lsp==2.3.0 in d:\projekty\sieci_neuronowe\.venv\lib\site-packages (from -r requirements.txt (line 47)) (2.3.0)
# Requirement already satisfied: jupyter_client==8.6.3 in d:\projekty\sieci_neuronowe\.venv\lib\site-packages (from -r requirements.txt (line 48)) (8.6.3)
# Requirement already satisfied: jupyter_core==5.9.1 in d:\projekty\sieci_neuronowe\.venv\lib\site-packages (from -r requirements.txt (line 49)) (5.9.1)
# Requirement already satisfied: jupyter_server==2.17.0 in d:\projekty\sieci_neuronowe\.venv\lib\site-packages (from -r requirements.txt (line 50)) (2.17.0)
# Requirement already satisfied: jupyter_server_terminals==0.5.3 in d:\projekty\sieci_neuronowe\.venv\lib\site-packages (from -r requirements.txt (line 51)) (0.5.3)
# Requirement already satisfied: jupyterlab==4.5.0 in d:\projekty\sieci_neuronowe\.venv\lib\site-packages (from -r requirements.txt (line 52)) (4.5.0)
# Requirement already satisfied: jupyterlab_pygments==0.3.0 in d:\projekty\sieci_neuronowe\.venv\lib\site-packages (from -r requirements.txt (line 53)) (0.3.0)
# Requirement already satisfied: jupyterlab_server==2.28.0 in d:\projekty\sieci_neuronowe\.venv\lib\site-packages (from -r requirements.txt (line 54)) (2.28.0)
# Requirement already satisfied: keyring==25.7.0 in d:\projekty\sieci_neuronowe\.venv\lib\site-packages (from -r requirements.txt (line 55)) (25.7.0)
# Requirement already satisfied: kiwisolver==1.4.9 in d:\projekty\sieci_neuronowe\.venv\lib\site-packages (from -r requirements.txt (line 56)) (1.4.9)
# Requirement already satisfied: lark==1.3.1 in d:\projekty\sieci_neuronowe\.venv\lib\site-packages (from -r requirements.txt (line 57)) (1.3.1)
# Requirement already satisfied: markdown-it-py==4.0.0 in d:\projekty\sieci_neuronowe\.venv\lib\site-packages (from -r requirements.txt (line 58)) (4.0.0)
# Requirement already satisfied: MarkupSafe==2.1.5 in d:\projekty\sieci_neuronowe\.venv\lib\site-packages (from -r requirements.txt (line 59)) (2.1.5)
# Requirement already satisfied: matplot==0.1.9 in d:\projekty\sieci_neuronowe\.venv\lib\site-packages (from -r requirements.txt (line 60)) (0.1.9)
# Requirement already satisfied: matplotlib==3.10.7 in d:\projekty\sieci_neuronowe\.venv\lib\site-packages (from -r requirements.txt (line 61)) (3.10.7)
# Requirement already satisfied: matplotlib-inline==0.2.1 in d:\projekty\sieci_neuronowe\.venv\lib\site-packages (from -r requirements.txt (line 62)) (0.2.1)
# Requirement already satisfied: mdurl==0.1.2 in d:\projekty\sieci_neuronowe\.venv\lib\site-packages (from -r requirements.txt (line 63)) (0.1.2)
# Requirement already satisfied: mistune==3.1.4 in d:\projekty\sieci_neuronowe\.venv\lib\site-packages (from -r requirements.txt (line 64)) (3.1.4)
# Requirement already satisfied: more-itertools==10.8.0 in d:\projekty\sieci_neuronowe\.venv\lib\site-packages (from -r requirements.txt (line 65)) (10.8.0)
# Requirement already satisfied: mpmath==1.3.0 in d:\projekty\sieci_neuronowe\.venv\lib\site-packages (from -r requirements.txt (line 66)) (1.3.0)
# Requirement already satisfied: nbclient==0.10.2 in d:\projekty\sieci_neuronowe\.venv\lib\site-packages (from -r requirements.txt (line 67)) (0.10.2)
# Requirement already satisfied: nbconvert==7.16.6 in d:\projekty\sieci_neuronowe\.venv\lib\site-packages (from -r requirements.txt (line 68)) (7.16.6)
# Requirement already satisfied: nbformat==5.10.4 in d:\projekty\sieci_neuronowe\.venv\lib\site-packages (from -r requirements.txt (line 69)) (5.10.4)
# Requirement already satisfied: nest-asyncio==1.6.0 in d:\projekty\sieci_neuronowe\.venv\lib\site-packages (from -r requirements.txt (line 70)) (1.6.0)
# Requirement already satisfied: networkx==3.5 in d:\projekty\sieci_neuronowe\.venv\lib\site-packages (from -r requirements.txt (line 71)) (3.5)
# Requirement already satisfied: nh3==0.3.2 in d:\projekty\sieci_neuronowe\.venv\lib\site-packages (from -r requirements.txt (line 72)) (0.3.2)
# Requirement already satisfied: notebook==7.5.0 in d:\projekty\sieci_neuronowe\.venv\lib\site-packages (from -r requirements.txt (line 73)) (7.5.0)
# Requirement already satisfied: notebook_shim==0.2.4 in d:\projekty\sieci_neuronowe\.venv\lib\site-packages (from -r requirements.txt (line 74)) (0.2.4)
# Requirement already satisfied: numpy==2.3.3 in d:\projekty\sieci_neuronowe\.venv\lib\site-packages (from -r requirements.txt (line 75)) (2.3.3)
# Requirement already satisfied: packaging==25.0 in d:\projekty\sieci_neuronowe\.venv\lib\site-packages (from -r requirements.txt (line 76)) (25.0)
# Requirement already satisfied: pandas==2.3.3 in d:\projekty\sieci_neuronowe\.venv\lib\site-packages (from -r requirements.txt (line 77)) (2.3.3)
# Requirement already satisfied: pandocfilters==1.5.1 in d:\projekty\sieci_neuronowe\.venv\lib\site-packages (from -r requirements.txt (line 78)) (1.5.1)
# Requirement already satisfied: parso==0.8.5 in d:\projekty\sieci_neuronowe\.venv\lib\site-packages (from -r requirements.txt (line 79)) (0.8.5)
# Requirement already satisfied: pillow==11.3.0 in d:\projekty\sieci_neuronowe\.venv\lib\site-packages (from -r requirements.txt (line 80)) (11.3.0)
# Requirement already satisfied: platformdirs==4.5.0 in d:\projekty\sieci_neuronowe\.venv\lib\site-packages (from -r requirements.txt (line 81)) (4.5.0)
# Requirement already satisfied: prometheus_client==0.23.1 in d:\projekty\sieci_neuronowe\.venv\lib\site-packages (from -r requirements.txt (line 82)) (0.23.1)
# Requirement already satisfied: prompt_toolkit==3.0.52 in d:\projekty\sieci_neuronowe\.venv\lib\site-packages (from -r requirements.txt (line 83)) (3.0.52)
# Requirement already satisfied: psutil==7.1.3 in d:\projekty\sieci_neuronowe\.venv\lib\site-packages (from -r requirements.txt (line 84)) (7.1.3)
# Requirement already satisfied: pure_eval==0.2.3 in d:\projekty\sieci_neuronowe\.venv\lib\site-packages (from -r requirements.txt (line 85)) (0.2.3)
# Requirement already satisfied: pycparser==2.23 in d:\projekty\sieci_neuronowe\.venv\lib\site-packages (from -r requirements.txt (line 86)) (2.23)
# Requirement already satisfied: Pygments==2.19.2 in d:\projekty\sieci_neuronowe\.venv\lib\site-packages (from -r requirements.txt (line 87)) (2.19.2)
# Requirement already satisfied: pyloco==0.0.139 in d:\projekty\sieci_neuronowe\.venv\lib\site-packages (from -r requirements.txt (line 88)) (0.0.139)
# Requirement already satisfied: pyparsing==3.2.5 in d:\projekty\sieci_neuronowe\.venv\lib\site-packages (from -r requirements.txt (line 89)) (3.2.5)
# Requirement already satisfied: python-dateutil==2.9.0.post0 in d:\projekty\sieci_neuronowe\.venv\lib\site-packages (from -r requirements.txt (line 90)) (2.9.0.post0)
# Requirement already satisfied: python-json-logger==4.0.0 in d:\projekty\sieci_neuronowe\.venv\lib\site-packages (from -r requirements.txt (line 91)) (4.0.0)
# Requirement already satisfied: pytz==2025.2 in d:\projekty\sieci_neuronowe\.venv\lib\site-packages (from -r requirements.txt (line 92)) (2025.2)
# Requirement already satisfied: pywin32-ctypes==0.2.3 in d:\projekty\sieci_neuronowe\.venv\lib\site-packages (from -r requirements.txt (line 93)) (0.2.3)
# Requirement already satisfied: pywinpty==3.0.2 in d:\projekty\sieci_neuronowe\.venv\lib\site-packages (from -r requirements.txt (line 94)) (3.0.2)
# Requirement already satisfied: PyYAML==6.0.3 in d:\projekty\sieci_neuronowe\.venv\lib\site-packages (from -r requirements.txt (line 95)) (6.0.3)
# Requirement already satisfied: pyzmq==27.1.0 in d:\projekty\sieci_neuronowe\.venv\lib\site-packages (from -r requirements.txt (line 96)) (27.1.0)
# Requirement already satisfied: readme_renderer==44.0 in d:\projekty\sieci_neuronowe\.venv\lib\site-packages (from -r requirements.txt (line 97)) (44.0)
# Requirement already satisfied: referencing==0.37.0 in d:\projekty\sieci_neuronowe\.venv\lib\site-packages (from -r requirements.txt (line 98)) (0.37.0)
# Requirement already satisfied: requests==2.32.5 in d:\projekty\sieci_neuronowe\.venv\lib\site-packages (from -r requirements.txt (line 99)) (2.32.5)
# Requirement already satisfied: requests-toolbelt==1.0.0 in d:\projekty\sieci_neuronowe\.venv\lib\site-packages (from -r requirements.txt (line 100)) (1.0.0)
# Requirement already satisfied: rfc3339-validator==0.1.4 in d:\projekty\sieci_neuronowe\.venv\lib\site-packages (from -r requirements.txt (line 101)) (0.1.4)
# Requirement already satisfied: rfc3986==2.0.0 in d:\projekty\sieci_neuronowe\.venv\lib\site-packages (from -r requirements.txt (line 102)) (2.0.0)
# Requirement already satisfied: rfc3986-validator==0.1.1 in d:\projekty\sieci_neuronowe\.venv\lib\site-packages (from -r requirements.txt (line 103)) (0.1.1)
# Requirement already satisfied: rfc3987-syntax==1.1.0 in d:\projekty\sieci_neuronowe\.venv\lib\site-packages (from -r requirements.txt (line 104)) (1.1.0)
# Requirement already satisfied: rich==14.2.0 in d:\projekty\sieci_neuronowe\.venv\lib\site-packages (from -r requirements.txt (line 105)) (14.2.0)
# Requirement already satisfied: rpds-py==0.29.0 in d:\projekty\sieci_neuronowe\.venv\lib\site-packages (from -r requirements.txt (line 106)) (0.29.0)
# Requirement already satisfied: Send2Trash==1.8.3 in d:\projekty\sieci_neuronowe\.venv\lib\site-packages (from -r requirements.txt (line 107)) (1.8.3)
# Requirement already satisfied: setuptools==70.2.0 in d:\projekty\sieci_neuronowe\.venv\lib\site-packages (from -r requirements.txt (line 108)) (70.2.0)
# Requirement already satisfied: SimpleWebSocketServer==0.1.2 in d:\projekty\sieci_neuronowe\.venv\lib\site-packages (from -r requirements.txt (line 109)) (0.1.2)
# Requirement already satisfied: six==1.17.0 in d:\projekty\sieci_neuronowe\.venv\lib\site-packages (from -r requirements.txt (line 110)) (1.17.0)
# Requirement already satisfied: sniffio==1.3.1 in d:\projekty\sieci_neuronowe\.venv\lib\site-packages (from -r requirements.txt (line 111)) (1.3.1)
# Requirement already satisfied: soupsieve==2.8 in d:\projekty\sieci_neuronowe\.venv\lib\site-packages (from -r requirements.txt (line 112)) (2.8)
# Requirement already satisfied: stack-data==0.6.3 in d:\projekty\sieci_neuronowe\.venv\lib\site-packages (from -r requirements.txt (line 113)) (0.6.3)
# Requirement already satisfied: sympy==1.14.0 in d:\projekty\sieci_neuronowe\.venv\lib\site-packages (from -r requirements.txt (line 114)) (1.14.0)
# Requirement already satisfied: terminado==0.18.1 in d:\projekty\sieci_neuronowe\.venv\lib\site-packages (from -r requirements.txt (line 115)) (0.18.1)
# Requirement already satisfied: tinycss2==1.4.0 in d:\projekty\sieci_neuronowe\.venv\lib\site-packages (from -r requirements.txt (line 116)) (1.4.0)
# Requirement already satisfied: torch==2.9.1+cu130 in d:\projekty\sieci_neuronowe\.venv\lib\site-packages (from -r requirements.txt (line 117)) (2.9.1+cu130)
# Requirement already satisfied: torchvision==0.24.1+cu130 in d:\projekty\sieci_neuronowe\.venv\lib\site-packages (from -r requirements.txt (line 118)) (0.24.1+cu130)
# Requirement already satisfied: tornado==6.5.2 in d:\projekty\sieci_neuronowe\.venv\lib\site-packages (from -r requirements.txt (line 119)) (6.5.2)
# Requirement already satisfied: traitlets==5.14.3 in d:\projekty\sieci_neuronowe\.venv\lib\site-packages (from -r requirements.txt (line 120)) (5.14.3)
# Requirement already satisfied: twine==6.2.0 in d:\projekty\sieci_neuronowe\.venv\lib\site-packages (from -r requirements.txt (line 121)) (6.2.0)
# Requirement already satisfied: typing==3.7.4.3 in d:\projekty\sieci_neuronowe\.venv\lib\site-packages (from -r requirements.txt (line 122)) (3.7.4.3)
# Requirement already satisfied: typing_extensions==4.15.0 in d:\projekty\sieci_neuronowe\.venv\lib\site-packages (from -r requirements.txt (line 123)) (4.15.0)
# Requirement already satisfied: tzdata==2025.2 in d:\projekty\sieci_neuronowe\.venv\lib\site-packages (from -r requirements.txt (line 124)) (2025.2)
# Requirement already satisfied: uri-template==1.3.0 in d:\projekty\sieci_neuronowe\.venv\lib\site-packages (from -r requirements.txt (line 125)) (1.3.0)
# Requirement already satisfied: urllib3==2.5.0 in d:\projekty\sieci_neuronowe\.venv\lib\site-packages (from -r requirements.txt (line 126)) (2.5.0)
# Requirement already satisfied: ushlex==0.99.1 in d:\projekty\sieci_neuronowe\.venv\lib\site-packages (from -r requirements.txt (line 127)) (0.99.1)
# Requirement already satisfied: wcwidth==0.2.14 in d:\projekty\sieci_neuronowe\.venv\lib\site-packages (from -r requirements.txt (line 128)) (0.2.14)
# Requirement already satisfied: webcolors==25.10.0 in d:\projekty\sieci_neuronowe\.venv\lib\site-packages (from -r requirements.txt (line 129)) (25.10.0)
# Requirement already satisfied: webencodings==0.5.1 in d:\projekty\sieci_neuronowe\.venv\lib\site-packages (from -r requirements.txt (line 130)) (0.5.1)
# Requirement already satisfied: websocket-client==1.9.0 in d:\projekty\sieci_neuronowe\.venv\lib\site-packages (from -r requirements.txt (line 131)) (1.9.0)
# [notice] A new release of pip is available: 25.1.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import torch
import torch.nn as nn
from pathlib import Path

from network.neural_network import build_model
from dataset.augmentation import RandomAugmentation
from solution.train import Trainer

# %%
DATA_PATH = "../data/"

def make_heads():
    head_cls = nn.Sequential(
        nn.Dropout(0.6),
        nn.Linear(256, 135),
    )

    head_cnt = nn.Sequential(
        nn.Dropout(0.5),
        nn.Linear(256, 128),
        nn.ReLU(),
        nn.Dropout(0.4),
        nn.Linear(128, 6),
    )
    return head_cls, head_cnt


def make_train_transform():
    return RandomAugmentation(
        p_hflip=0.4,
        p_vflip=0.4,
        p_rotate90=0.4,
        p_brightness=0.4,
        p_noise=0.4,
    )


def run_experiment(
    *,
    lambda_cnt: float,
    regression_only: bool,
    max_epochs: int = 100,
    target_accuracy: float = 0.5,
    experiment_name: str = "",
):
    torch.manual_seed(1)
    if torch.cuda.is_available():
        torch.cuda.manual_seed_all(1)

    head_cls, head_cnt = make_heads()

    config = {
        "lambda_cnt": lambda_cnt,
    }

    model = build_model(
        config=config,
        head_cls=head_cls,
        head_cnt=head_cnt,
    )

    train_transform = make_train_transform()

    trainer = Trainer(
        data_dir=Path(DATA_PATH),
        model=model,
        train_transform=train_transform,
    )

    print(
        f"\n=== Starting experiment: {experiment_name} "
        f"(lambda_cnt={lambda_cnt}, regression_only={regression_only}) ==="
    )

    history = trainer.train(
        epochs=max_epochs,
        verbose=True,
        target_accuracy=target_accuracy,
        regression_only=regression_only,
    )

    trainer.plot_losses(title=f"{experiment_name} – loss")
    trainer.plot_validation_metrics(title=f"{experiment_name} – val metrics")
    trainer.plot_confusion_matrix(
        title=f"{experiment_name} – Val confusion matrix",
        normalize=True,
    )
    trainer.report_best_worst_classes(k=20)

    return trainer, history


def run_classification_only():
    return run_experiment(
        lambda_cnt=0.0,
        regression_only=False,
        max_epochs=100,
        target_accuracy=0.5,
        experiment_name="classification_only",
    )


def run_regression_only():

    return run_experiment(
        lambda_cnt=1.0,
        regression_only=True,
        max_epochs=100,
        target_accuracy=1.0,
        experiment_name="regression_only",
    )


def run_multitask(lambda_cnt: float = 0.3):
    """Eksperyment 3: multitask z wybranym lambda_cnt."""
    return run_experiment(
        lambda_cnt=lambda_cnt,
        regression_only=False,
        max_epochs=100,
        target_accuracy=0.5,
        experiment_name=f"multitask_lambda_{lambda_cnt}",
    )

# %%
trainer_reg, hist_reg = run_regression_only()
trainer_cls, hist_cls = run_classification_only()
trainer_multi, hist_multi = run_multitask(lambda_cnt=1.4)
# Out:
# === Starting experiment: regression_only (lambda_cnt=1.0, regression_only=True) ===
# D:\Projekty\sieci_neuronowe\dataset\dataset.py:93: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   arr = torch.ByteTensor(torch.ByteStorage.from_buffer(image.tobytes()))
# Epoch 1: train_loss=1.4154 cls=0.0000 cnt=1.4154
#           val_loss=6.2459 acc=0.0110 rmse=2.6897 mae=1.6492
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 trainer_reg, hist_reg = run_regression_only()
#       2 trainer_cls, hist_cls = run_classification_only()
#       3 trainer_multi, hist_multi = run_multitask(lambda_cnt=1.4)
#
# Cell In[3], line 96, in run_regression_only()
#      94 def run_regression_only():
# ---> 96     return run_experiment(
#      97         lambda_cnt=1.0,
#      98         regression_only=True,
#      99         max_epochs=100,
#     100         target_accuracy=1.0,
#     101         experiment_name="regression_only",
#     102     )
#
# Cell In[3], line 66, in run_experiment(lambda_cnt, regression_only, max_epochs, target_accuracy, experiment_name)
#      55 trainer = Trainer(
#      56     data_dir=Path(DATA_PATH),
#      57     model=model,
#      58     train_transform=train_transform,
#      59 )
#      61 print(
#      62     f"\n=== Starting experiment: {experiment_name} "
#      63     f"(lambda_cnt={lambda_cnt}, regression_only={regression_only}) ==="
#      64 )
# ---> 66 history = trainer.train(
#      67     epochs=max_epochs,
#      68     verbose=True,
#      69     target_accuracy=target_accuracy,
#      70     regression_only=regression_only,
#      71 )
#      73 trainer.plot_losses(title=f"{experiment_name} – loss")
#      74 trainer.plot_validation_metrics(title=f"{experiment_name} – val metrics")
#
# File D:\Projekty\sieci_neuronowe\solution\train.py:224, in Trainer.train(self, epochs, verbose, target_accuracy, regression_only)
#     221 for epoch in range(1, epochs + 1):
#     222     # 1) standard vs regression-only training step
#     223     if regression_only:
# --> 224         train_stats = train_one_epoch_regression_only(self.model, self.train_loader, self.device)
#     225     else:
#     226         train_stats = train_one_epoch(self.model, self.train_loader, self.device)
#
# File D:\Projekty\sieci_neuronowe\solution\train.py:120, in train_one_epoch_regression_only(model, loader, device)
#     113 all_params = (
#     114     list(model.backbone.parameters())
#     115     + list(model.head_cls.parameters())
#     116     + list(model.head_cnt.parameters())
#     117 )
#     118 max_grad_norm = getattr(model, "max_grad_norm", 0.0)
# --> 120 for inputs, _, counts_targets in loader:
#     121     inputs = inputs.to(device)
#     122     counts_targets = counts_targets.to(device)
#
# File D:\Projekty\sieci_neuronowe\.venv\Lib\site-packages\torch\utils\data\dataloader.py:732, in _BaseDataLoaderIter.__next__(self)
#     729 if self._sampler_iter is None:
#     730     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     731     self._reset()  # type: ignore[call-arg]
# --> 732 data = self._next_data()
#     733 self._num_yielded += 1
#     734 if (
#     735     self._dataset_kind == _DatasetKind.Iterable
#     736     and self._IterableDataset_len_called is not None
#     737     and self._num_yielded > self._IterableDataset_len_called
#     738 ):
#
# File D:\Projekty\sieci_neuronowe\.venv\Lib\site-packages\torch\utils\data\dataloader.py:788, in _SingleProcessDataLoaderIter._next_data(self)
#     786 def _next_data(self):
#     787     index = self._next_index()  # may raise StopIteration
# --> 788     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     789     if self._pin_memory:
#     790         data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# File D:\Projekty\sieci_neuronowe\.venv\Lib\site-packages\torch\utils\data\_utils\fetch.py:50, in _MapDatasetFetcher.fetch(self, possibly_batched_index)
#      48 if self.auto_collation:
#      49     if hasattr(self.dataset, "__getitems__") and self.dataset.__getitems__:
# ---> 50         data = self.dataset.__getitems__(possibly_batched_index)
#      51     else:
#      52         data = [self.dataset[idx] for idx in possibly_batched_index]
#
# File D:\Projekty\sieci_neuronowe\.venv\Lib\site-packages\torch\utils\data\dataset.py:416, in Subset.__getitems__(self, indices)
#     414     return self.dataset.__getitems__([self.indices[idx] for idx in indices])  # type: ignore[attr-defined]
#     415 else:
# --> 416     return [self.dataset[self.indices[idx]] for idx in indices]
#
# File D:\Projekty\sieci_neuronowe\solution\train.py:25, in MultiTaskShapesDataset.__getitem__(self, idx)
#      24 def __getitem__(self, idx: int):
# ---> 25     image, counts = self.base[idx]
#      26     if image.shape[0] != 1:
#      27         image = image.mean(dim=0, keepdim=True)
#
# File D:\Projekty\sieci_neuronowe\dataset\dataset.py:79, in ShapesDataset.__getitem__(self, idx)
#      76     raise FileNotFoundError(f"Image file not found: {img_path}")
#      78 image = Image.open(img_path).convert("RGB")
# ---> 79 image_tensor = self._pil_to_tensor(image)
#      81 labels = [row[self._label_columns[key]] for key in sorted(self._label_columns)]
#      82 labels_tensor = torch.tensor(labels, dtype=torch.float32)
#
# File D:\Projekty\sieci_neuronowe\dataset\dataset.py:96, in ShapesDataset._pil_to_tensor(image)
#      94 h, w = image.size[1], image.size[0]
#      95 c = 3
# ---> 96 arr = arr.view(h, w, c).permute(2, 0, 1).to(dtype=torch.float32) / 255.0
#      97 return arr
#
# KeyboardInterrupt:
